# %%
import pandas as pd

# %%
data=pd.read_excel('Customer Call List.xlsx')

# %%
data
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
data=data.drop(columns='Not_Useful_Column')

# %%
data
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
data['Last_Name']=data['Last_Name'].str.strip('/,.,_')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
data[['Hse_No', 'State', 'Zipcode']]=data['Address'].str.split(' ', n=2,expand=True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
data =data.drop(columns ='Address')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Paying Customer']=data['Paying Customer'].str.replace('Y', 'Yes')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Paying Customer']=data['Paying Customer'].str.replace('No', 'N')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Paying Customer']=data['Paying Customer'].str.replace('No', 'N')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775               N
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN               N
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Paying Customer']=data['Paying Customer'].str.replace('N', 'No')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Do_Not_Contact']=data['Do_Not_Contact'].str.replace('No', 'N')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Do_Not_Contact']=data['Do_Not_Contact'].str.replace('N', 'No')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Do_Not_Contact']=data['Do_Not_Contact'].str.replace('Yes', 'Y')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Do_Not_Contact']=data['Do_Not_Contact'].str.replace('Yes', 'Y')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Do_Not_Contact']=data['Do_Not_Contact'].str.replace('Y', 'Yes')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data['Last_Name']=data['Last_Name'].dropna()

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger           NaN              No
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee           NaN             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
data.dropna(subset = ['Phone_Number'],inplace= True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# ...

# %%
data['Do_Not_Contact']=data['Do_Not_Contact'].str.replace('N/a', ' ')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN           N/a             Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter    7066950392             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# ...

# %%
data['Phone_Number']=data['Phone_Number'].str.replace('N/a', ' ')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White           NaN              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 11        1012      Harry      Potter           NaN             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# ...

# %%
data.dropna(subset = ['Phone_Number'],inplace= True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
data=data.replace('No/a','')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
data=data.replace('N/a','')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
data=data.fillna('')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf                                       Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
data['Phone_Number']=data['Phone_Number'].str.replace('[^a-zA-Z0-9]',' ')

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf                                       Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
data
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469             Yes
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 7         1008   Sherlock      Holmes  876|678|3469              No
# 8         1009    Gandalf                                       Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 12        1013        Don      Draper  123-543-2345             Yes
# 13        1014     Leslie       Knope  876|678|3469             Yes
# 14        1015       Toby  Flenderson  304-762-2467              No
# 15        1016        Ron     Weasley  123-545-5421              No
# 16        1017   Michael        Scott  123/643/9775             Yes
# ...

# %%
data['Phone_Number'].str.replace('[^a-zA-Z0-9]',' ')
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 7     876|678|3469
# 8
# 9     123-545-5421
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 18
# 19    876|678|3469
# 20    876|678|3469
# Name: Phone_Number, dtype: object

# %%
 data['Phone_Number'].str.replace('[^\d]', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Benson\AppData\Local\Temp\ipykernel_9596\1731698399.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['Phone_Number'].str.replace('[^\d]', '', regex=True)
# 0     1235455421
# 1     1236439775
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 7     8766783469
# 8
# 9     1235455421
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 18
# 19    8766783469
# 20    8766783469
# Name: Phone_Number, dtype: object

# %%
data['Phone_Number'] = data['Phone_Number'].str.replace(r'[^\d]', '', regex=True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1002       Abed       Nadir   1236439775              No
# 3         1004     Dwight     Schrute   1235432345             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 5         1006        Ron     Swanson   3047622467             Yes
# 7         1008   Sherlock      Holmes   8766783469              No
# 8         1009    Gandalf                                      Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# 14        1015       Toby  Flenderson   3047622467              No
# 15        1016        Ron     Weasley   1235455421              No
# 16        1017   Michael        Scott   1236439775             Yes
# ...

# %%
for x in data.index:
    if data.loc[x, 'Do_Not_Contact']=='Yes':
        data.drop(x, inplace = True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 7         1008   Sherlock      Holmes   8766783469              No
# 8         1009    Gandalf                                      Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# 14        1015       Toby  Flenderson   3047622467              No
# 15        1016        Ron     Weasley   1235455421              No
# 16        1017   Michael        Scott   1236439775             Yes
# 19        1020     Anakin   Skywalker   8766783469             Yes
# 20        1020     Anakin   Skywalker   8766783469             Yes
#
#    Do_Not_Contact Hse_No     State               Zipcode
# ...

# %%
for x in data.index:
    if data.loc[x, 'Phone_Number']==' ':
        data.drop(x, inplace = True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 7         1008   Sherlock      Holmes   8766783469              No
# 8         1009    Gandalf                                      Yes
# 9         1010      Peter      Parker   1235455421             Yes
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# 14        1015       Toby  Flenderson   3047622467              No
# 15        1016        Ron     Weasley   1235455421              No
# 16        1017   Michael        Scott   1236439775             Yes
# 19        1020     Anakin   Skywalker   8766783469             Yes
# 20        1020     Anakin   Skywalker   8766783469             Yes
#
#    Do_Not_Contact Hse_No     State               Zipcode
# ...

# %%
for x in data.index:
    if data.loc[x,'Phone_Number']=='':
        data.drop(x, inplace = True)

# %%
data
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 7         1008   Sherlock      Holmes   8766783469              No
# 9         1010      Peter      Parker   1235455421             Yes
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# 14        1015       Toby  Flenderson   3047622467              No
# 15        1016        Ron     Weasley   1235455421              No
# 16        1017   Michael        Scott   1236439775             Yes
# 19        1020     Anakin   Skywalker   8766783469             Yes
# 20        1020     Anakin   Skywalker   8766783469             Yes
#
#    Do_Not_Contact Hse_No     State               Zipcode
# 0              No    123     Shire           Lane, Shire
# ...

# %%
data.reset_index(drop=True)
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 1         1005        Jon        Snow   8766783469             Yes
# 2         1008   Sherlock      Holmes   8766783469              No
# 3         1010      Peter      Parker   1235455421             Yes
# 4         1013        Don      Draper   1235432345             Yes
# 5         1014     Leslie       Knope   8766783469             Yes
# 6         1015       Toby  Flenderson   3047622467              No
# 7         1016        Ron     Weasley   1235455421              No
# 8         1017   Michael        Scott   1236439775             Yes
# 9         1020     Anakin   Skywalker   8766783469             Yes
# 10        1020     Anakin   Skywalker   8766783469             Yes
#
#    Do_Not_Contact Hse_No     State               Zipcode
# 0              No    123     Shire           Lane, Shire
# ...

# %%
data
# Out:
#     CustomerID First_Name   Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins   1235455421             Yes
# 4         1005        Jon        Snow   8766783469             Yes
# 7         1008   Sherlock      Holmes   8766783469              No
# 9         1010      Peter      Parker   1235455421             Yes
# 12        1013        Don      Draper   1235432345             Yes
# 13        1014     Leslie       Knope   8766783469             Yes
# 14        1015       Toby  Flenderson   3047622467              No
# 15        1016        Ron     Weasley   1235455421              No
# 16        1017   Michael        Scott   1236439775             Yes
# 19        1020     Anakin   Skywalker   8766783469             Yes
# 20        1020     Anakin   Skywalker   8766783469             Yes
#
#    Do_Not_Contact Hse_No     State               Zipcode
# 0              No    123     Shire           Lane, Shire
# ...
