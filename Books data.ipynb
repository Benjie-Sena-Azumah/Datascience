# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print (pd.__version__)
# Out:
# 2.2.3

# %%
print (np.__version__)
# Out:
# 2.2.2

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
data=pd.read_csv('Books_Data_Clean.csv')

# %%
data.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
data.shape
# Out:
# (1070, 15)

# %%
data.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
data= data[data['Publishing Year']>1900]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data= data[data['Publishing Year']>1900]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
# ...

# %%
data.describe()
# Out:
# count     1070
# unique       2
# top       True
# freq      1009
# Name: Publishing Year, dtype: object

# %%
data
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1065    True
# 1066    True
# 1067    True
# 1068    True
# 1069    True
# Name: Publishing Year, Length: 1070, dtype: bool

# %%
df = pd.read_csv('Books_Data_Clean.csv')

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df['language_code']= 'English'

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney       English
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...       English
# ...

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         1
# Book Name              23
# Author                  0
# language_code           0
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.loc[0]
#
# NameError: name 'df' is not defined

# %%
df =pd.read_csv('Books_Data_Clean.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df =pd.read_csv('Books_Data_Clean.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df =pd.read_csv('Books_Data_Clean.csv')

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.loc[0]
# Out:
# index                                         0
# Publishing Year                          1975.0
# Book Name                               Beowulf
# Author                   Unknown, Seamus Heaney
# language_code                             en-US
# Author_Rating                            Novice
# Book_average_rating                        3.42
# Book_ratings_count                       155903
# genre                             genre fiction
# gross sales                             34160.0
# publisher revenue                       20496.0
# sale price                                 4.88
# sales rank                                    1
# Publisher              HarperCollins Publishers
# units sold                                 7000
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# index                                                                  1
# Publishing Year                                                   1987.0
# Book Name                                               Batman: Year One
# Author                 Frank Miller, David Mazzucchelli, Richmond Lew...
# language_code                                                        eng
# Author_Rating                                               Intermediate
# Book_average_rating                                                 4.23
# Book_ratings_count                                                145267
# genre                                                      genre fiction
# gross sales                                                      12437.5
# publisher revenue                                                 7462.5
# sale price                                                          1.99
# sales rank                                                             2
# ...

# %%
df.loc[[0,1]]
# Out:
#    index  Publishing Year         Book Name  \
# 0      0           1975.0           Beowulf
# 1      1           1987.0  Batman: Year One
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
#
#                  Publisher   units sold
# 0  HarperCollins Publishers        7000
# 1  HarperCollins Publishers        6250

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
df['Book_average_rating'].mode()
# Out:
# 0    4.16
# Name: Book_average_rating, dtype: float64

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df=df[df['Publishing Year']>1900]

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1009.000000      1009.000000          1009.000000         1009.000000
# mean    535.926660      1994.730426             4.012230        94817.793855
# std     308.769358        23.204719             0.246492        31473.890412
# min       0.000000      1901.000000             2.970000        27308.000000
# 25%     271.000000      1989.000000             3.860000        70701.000000
# 50%     535.000000      2003.000000             4.030000        89204.000000
# 75%     802.000000      2010.000000             4.180000       113400.000000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1009.000000        1009.000000  1009.000000  1009.000000   1009.000000
# mean    1832.644985         841.360638     4.844311   613.314172   9744.482656
# ...

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name              21
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dropna(subset ='Book Name', inplace=True)
# Out:
# C:\Users\Benson\AppData\Local\Temp\ipykernel_2008\2953518573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset ='Book Name', inplace= True)

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Publishing Year'])
plt.xlabel('Publishing Year')
plt.ylabel('frequency')
plt.title('Distribution of publishing')
plt.show()

# %%
df['genre'].value_counts().plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Number of books per Genre')
plt.title('Distribution of books per Genre')
plt.show()

# %%
df.groupby('Author')['Book_average_rating'].mean().sort_values(ascending= False)
# Out:
# Author
# Bill Watterson                  4.650000
# Bill Watterson, G.B. Trudeau    4.610000
# J.R.R. Tolkien                  4.590000
# George R.R. Martin              4.560000
# Sarah J. Maas                   4.526000
#                                   ...
# Chetan Bhagat                   3.273333
# Audrey Niffenegger              3.230000
# Herman Koch, Sam Garrett        3.220000
# P.D. James                      3.210000
# Sue Monk Kidd                   3.100000
# Name: Book_average_rating, Length: 669, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(x='genre', y='Book_ratings_count', data= df)
# Out:
# <Axes: xlabel='genre', ylabel='Book_ratings_count'>

# %%
plt.scatter(df['sale price'], df['units sold'])
plt.xlabel('sale price')
plt.ylabel('units sold')
plt.title('Scattered plot of sale price vs units sold')
plt.show()

# %%
language_counts=df['language_code'].value_counts()

# %%
language_counts
# Out:
# language_code
# eng      670
# en-US    226
# en-GB     29
# en-CA      7
# fre        4
# spa        2
# ara        2
# nl         1
# Name: count, dtype: int64

# %%
plt.pie(language_counts, labels = language_counts.index,startangle=90 , autopct= '%1.1f%%')
plt.title('Language distribtion')
plt.show()

# %%
df.groupby('Publisher ')['publisher revenue'].sum().sort_values(ascending= False)
# Out:
# Publisher
# Penguin Group (USA) LLC                 191581.104
# Random House LLC                        174956.244
# Amazon Digital Services,  Inc.          141767.772
# HarperCollins Publishers                121769.814
# Hachette Book Group                     107410.968
# Simon and Schuster Digital Sales Inc     46858.206
# Macmillan                                31249.830
# HarperCollins Publishing                  2830.806
# HarperCollins Christian Publishing        2135.670
# Name: publisher revenue, dtype: float64

# %%
df.groupby('Author_Rating')['Book_average_rating'].mean().sort_values(ascending=False)
# Out:
# Author_Rating
# Famous          4.437708
# Excellent       4.164821
# Intermediate    3.911753
# Novice          3.370714
# Name: Book_average_rating, dtype: float64

# %%
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
plt.scatter(df['Book_average_rating'],df['Book_ratings_count'])
plt.title('scatter plot of book average rating and book ratings counts')
plt.xlabel('Book average rating')
plt.ylabel('Book ratings count')
# Out:
# Text(0, 0.5, 'Book ratings count')

# %%
df.groupby('Author')['gross sales'].sum().head(10).plot(kind='line')
plt.xlabel('Author')
plt.ylabel('Gross sales')
plt.title('Line graph for Author vs Gross Sales')
plt.show()
