# %%
import pandas as pd

# %%
data=pd.read_csv('Iris_modified.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           NaN
# 1      2            4.9           3.0            1.4           NaN
# 2      2            4.9           3.0            1.4           NaN
# 3      3            4.7           3.2            NaN           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 149  146            6.7           3.0            5.2           2.3
# 150  147            6.3           NaN            5.0           1.9
# 151  148            6.5           3.0            5.2           2.0
# 152  149            6.2           3.4            5.4           2.3
# 153  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           NaN
# 1      2            4.9           3.0            1.4           NaN
# 2      2            4.9           3.0            1.4           NaN
# 3      3            4.7           3.2            NaN           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 149  146            6.7           3.0            5.2           2.3
# 150  147            6.3           NaN            5.0           1.9
# 151  148            6.5           3.0            5.2           2.0
# 152  149            6.2           3.4            5.4           2.3
# 153  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             154 non-null    int64
#  1   SepalLengthCm  153 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  152 non-null    float64
#  4   PetalWidthCm   147 non-null    float64
#  5   Species        154 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           NaN
# 1      2            4.9           3.0            1.4           NaN
# 2      2            4.9           3.0            1.4           NaN
# 3      3            4.7           3.2            NaN           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 149  146            6.7           3.0            5.2           2.3
# 150  147            6.3           NaN            5.0           1.9
# 151  148            6.5           3.0            5.2           2.0
# 152  149            6.2           3.4            5.4           2.3
# 153  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sepallength_mean=data.SepalLengthCm.mean()
sepalwidth_mean=data.SepalWidthCm.mean()
petallength_mean=data.PetalLengthCm.mean()
petalwidth_mean=data.PetalWidthCm.mean()

# %%
sepallength_mean
# Out:
# np.float64(5.827450980392157)

# %%
sepallength_mean
# Out:
# np.float64(5.827450980392157)

# %%
sepalwidth_mean=data.SepalWidthCm.mean()

# %%
sepalwidth_mean
# Out:
# np.float64(3.0433333333333334)

# %%
petallength_mean=data.PetalLengthCm.mean()

# %%
petallength_mean
# Out:
# np.float64(3.746052631578947)

# %%
petalwidth_mean=data.PetalWidthCm.mean()

# %%
petalwidth_mean
# Out:
# np.float64(1.195918367346939)

# %%
data['SepalLengthCm']=data['SepalLengthCm'].fillna(sepallength_mean)

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           NaN
# 1      2            4.9           3.0            1.4           NaN
# 2      2            4.9           3.0            1.4           NaN
# 3      3            4.7           3.2            NaN           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 149  146            6.7           3.0            5.2           2.3
# 150  147            6.3           NaN            5.0           1.9
# 151  148            6.5           3.0            5.2           2.0
# 152  149            6.2           3.4            5.4           2.3
# 153  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data['SepalWidthCm']=data['SepalWidthCm'].fillna(sepalwidth_mean)

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1      3.500000            1.4           NaN
# 1      2            4.9      3.000000            1.4           NaN
# 2      2            4.9      3.000000            1.4           NaN
# 3      3            4.7      3.200000            NaN           0.2
# 4      4            4.6      3.100000            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 149  146            6.7      3.000000            5.2           2.3
# 150  147            6.3      3.043333            5.0           1.9
# 151  148            6.5      3.000000            5.2           2.0
# 152  149            6.2      3.400000            5.4           2.3
# 153  150            5.9      3.000000            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data['PetalLengthCm']=data['PetalLengthCm'].fillna(petallength_mean)

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1